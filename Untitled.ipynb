# %%
import pandas as pd

# %%
def simpleFunction(filePath):
    parsed_file = pd.read_csv(filePath, header=None, delimiter='|')
    print(parsed_file)

# %%
simpleFunction('files/CIRT_2018-8_122018.csv')
# Out:
#         0         1       2   3                                          4    \
# 0      5105  91573965  102018   R                         Quicken Loans Inc.
# 1      5105  91573966  102018   R                     Wells Fargo Bank, N.A.
# 2      5105  91573967  102018   R                         Quicken Loans Inc.
# 3      5105  91573968  102018   R                                      Other
# 4      5105  91573969  102018   R                         Quicken Loans Inc.
# 5      5105  91573970  102018   C                              SunTrust Bank
# 6      5105  91573971  102018   C                                      Other
# 7      5105  91573972  102018   R                                      Other
# 8      5105  91573973  102018   R                         Quicken Loans Inc.
# 9      5105  91573974  102018   R                         Quicken Loans Inc.
# 10     5105  91573975  102018   R                                      Other
# ...

# %%
simpleFunction('files/CIRT_2018-8_012019.csv')
# Out:
#         0         1       2   3                                          4    \
# 0      5105  91573965  112018   R                         Quicken Loans Inc.
# 1      5105  91573966  112018   R                     Wells Fargo Bank, N.A.
# 2      5105  91573967  112018   R                         Quicken Loans Inc.
# 3      5105  91573968  112018   R                                      Other
# 4      5105  91573969  112018   R                         Quicken Loans Inc.
# 5      5105  91573970  112018   C                              SunTrust Bank
# 6      5105  91573971  112018   C                                      Other
# 7      5105  91573972  112018   R                                      Other
# 8      5105  91573973  112018   R                         Quicken Loans Inc.
# 9      5105  91573974  112018   R                         Quicken Loans Inc.
# 10     5105  91573975  112018   R                                      Other
# ...

# %%
simpleFunction('files/CIRT_2016-9_012017.csv')
# Out:
#         0         1       2   3                                  4    \
# 0      1462  37262251  112016   R                              Other
# 1      1462  37262252  112016   R                              Other
# 2      1462  37262253  112016   R                              Other
# 3      1462  37262254  112016   C                              Other
# 4      1462  37262255  112016   B                              Other
# 5      1462  37262256  112016   B                              Other
# 6      1462  37262257  112016   B                              Other
# 7      1462  37262258  112016   C                              Other
# 8      1462  37262259  112016   C                              Other
# 9      1462  37262260  112016   B                              Other
# 10     1462  37262261  112016   B                              Other
# 11     1462  37262262  112016   B                              Other
# 12     1462  37262263  112016   C                              Other
# ...
